# %%
import os, sys; sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import importlib
from src import data_loader
importlib.reload(data_loader)

from src.data_loader import load_parquet



df = load_parquet("recipes_enriched.parquet")

df.info()
df.head()
# Out:
# ✅ recipes_enriched.parquet chargé (231637 lignes, 23 colonnes)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                231636 non-null  object
#  1   id                  231637 non-null  int64
#  2   minutes             231637 non-null  int64
#  3   contributor_id      231637 non-null  int64
#  4   submitted           231637 non-null  datetime64[ns]
#  5   tags                231637 non-null  object
#  6   nutrition           231637 non-null  object
#  7   n_steps             231637 non-null  int64
#  8   steps               231637 non-null  object
#  9   description         226658 non-null  object
#  10  ingredients         231637 non-null  object
#  11  n_ingredients       231637 non-null  int64
#  12  calories            231637 non-null  float64
# ...

# %%
import importlib
from src import data_loader
importlib.reload(data_loader)
from src.data_loader import load_parquet_safe  # ou load_csv_safe

df = load_parquet_safe("recipes_enriched.parquet")  # normalise tags/ingredients/steps

# Vérifications rapides (types + exemple)
print(type(df["tags"].iloc[0]), type(df["ingredients"].iloc[0]))
print(df["tags"].head(3).tolist())
# Out:
# ✅ recipes_enriched.parquet chargé (231637 lignes, 23 colonnes)
# ✅ recipes_enriched.parquet chargé & normalisé (colonnes liste: ['tags', 'ingredients', 'steps'])
# <class 'list'> <class 'list'>
# [['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'side-dishes', 'vegetables', 'mexican', 'easy', 'fall', 'holiday-event', 'vegetarian', 'winter', 'dietary', 'christmas', 'seasonal', 'squash'], ['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'breakfast', 'main-dish', 'pork', 'american', 'oven', 'easy', 'kid-friendly', 'pizza', 'dietary', 'northeastern-united-states', 'meat', 'equipment'], ['time-to-make', 'course', 'preparation', 'main-dish', 'chili', 'crock-pot-slow-cooker', 'dietary', 'equipment', '4-hours-or-less']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                231636 non-null  object
#  1   id                  231637 non-null  int64
#  2   minutes             231637 non-null  int64
#  3   contributor_id      231637 non-null  int64
#  4   submitted           231637 non-null  datetime64[ns]
#  5   tags                231637 non-null  object
#  6   nutrition           231637 non-null  object
#  7   n_steps             231637 non-null  int64
#  8   steps               231637 non-null  object
#  9   description         226658 non-null  object
#  10  ingredients         231637 non-null  object
#  11  n_ingredients       231637 non-null  int64
#  12  calories            231637 non-null  float64
#  13  total_fat           231637 non-null  float64
#  14  sugar               231637 non-null  float64
# ...

# %%
from src.preprocessing import convert_recipes_for_univariate, RecipeConversionConfig

recipes_converted = convert_recipes_for_univariate(recipes_)
